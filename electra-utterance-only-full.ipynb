# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/README.md
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/labels.txt
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/gitattributes
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/mapping_emotions.json
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less_small/dev.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less_small/test.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less_small/train.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full_small/dev.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full_small/test.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full_small/train.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/dev.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/test.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/train.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full/dev.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full/test.jsonl
# /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-full/train.jsonl

# %%
# ============================================================
# MODEL: ELECTRA Utterance-Only Full
# Input: utterance only
# Dataset: context-less
# Figures folder + ZIP created after training
# ============================================================

import os
import json
import random
import shutil
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup
from torch.optim import AdamW

from sklearn.metrics import (
    f1_score,
    precision_score,
    recall_score,
    classification_report
)

from tqdm.auto import tqdm

warnings.filterwarnings("ignore")
os.environ["TOKENIZERS_PARALLELISM"] = "false"


# ============================================================
# 1. Configuration
# ============================================================

class CFG:
    DATA_ROOT = Path("/kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset")

    # FULL utterance-only dataset
    TRAIN_FILE = DATA_ROOT / "context-less/train.jsonl"
    DEV_FILE   = DATA_ROOT / "context-less/dev.jsonl"
    TEST_FILE  = DATA_ROOT / "context-less/test.jsonl"
    LABEL_FILE = DATA_ROOT / "labels.txt"

    MODEL_NAME = "google/electra-base-discriminator"

    MAX_LEN = 256
    BATCH_SIZE = 8
    EPOCHS = 3

    LR = 2e-5
    WEIGHT_DECAY = 0.01
    WARMUP_RATIO = 0.10

    LABEL_THRESHOLD = 0.30
    DEFAULT_PRED_THRESHOLD = 0.30

    SEED = 42

    OUTPUT_DIR = Path("/kaggle/working/electra_utterance_only_full")
    FIGURE_DIR = OUTPUT_DIR / "ELECTRA_utterance_only_full_figures"
    FIGURE_ZIP_NAME = OUTPUT_DIR / "ELECTRA_utterance_only_full_figures"


CFG.OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
CFG.FIGURE_DIR.mkdir(parents=True, exist_ok=True)

print("Train file:", CFG.TRAIN_FILE)
print("Dev file:", CFG.DEV_FILE)
print("Test file:", CFG.TEST_FILE)
print("Label file:", CFG.LABEL_FILE)
print("Output dir:", CFG.OUTPUT_DIR)
print("Figure dir:", CFG.FIGURE_DIR)


# ============================================================
# 2. Check Files
# ============================================================

for file_path in [CFG.TRAIN_FILE, CFG.DEV_FILE, CFG.TEST_FILE, CFG.LABEL_FILE]:
    if not file_path.exists():
        raise FileNotFoundError(f"File not found: {file_path}")

print("\nAll required files found.")


# ============================================================
# 3. Reproducibility
# ============================================================

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True


set_seed(CFG.SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("\nDevice:", device)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))


# ============================================================
# 4. Load Labels
# ============================================================

def load_labels(path):
    labels = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            label = line.strip()
            if label:
                labels.append(label)
    return labels


LABELS = load_labels(CFG.LABEL_FILE)
NUM_LABELS = len(LABELS)

id2label = {i: label for i, label in enumerate(LABELS)}
label2id = {label: i for i, label in enumerate(LABELS)}

print("\nNumber of labels:", NUM_LABELS)
print(LABELS)


# ============================================================
# 5. Inspect Raw Sample
# ============================================================

with open(CFG.TRAIN_FILE, "r", encoding="utf-8") as f:
    raw_sample = json.loads(f.readline())

print("\nRaw sample keys:")
print(raw_sample.keys())

print("\nRaw sample preview:")
print(json.dumps(raw_sample, indent=2, ensure_ascii=False)[:3000])


# ============================================================
# 6. Dataset Helper Functions
# ============================================================

def get_utterance(record):
    possible_keys = [
        "utterance",
        "original_utterance",
        "text",
        "sentence"
    ]

    for key in possible_keys:
        value = record.get(key, "")
        if isinstance(value, str) and value.strip():
            return value.strip()

    return ""


def get_label_indices(record):
    possible_keys = [
        "labels",
        "label",
        "emotions",
        "emotion_labels"
    ]

    for key in possible_keys:
        value = record.get(key, None)
        if value is not None:
            return value

    return []


def get_expressiveness(record):
    possible_keys = [
        "expressiveness",
        "scores",
        "label_scores",
        "emotion_scores"
    ]

    for key in possible_keys:
        value = record.get(key, None)
        if value is not None:
            return value

    return []


def make_multihot(label_values, expressiveness, num_labels, threshold=0.30):
    y = np.zeros(num_labels, dtype=np.float32)

    if label_values is None:
        return y

    if not isinstance(label_values, list):
        label_values = [label_values]

    if expressiveness is None or expressiveness == []:
        expressiveness = [1.0] * len(label_values)

    if not isinstance(expressiveness, list):
        expressiveness = [expressiveness] * len(label_values)

    if len(expressiveness) < len(label_values):
        expressiveness = expressiveness + [1.0] * (len(label_values) - len(expressiveness))

    for label_value, score in zip(label_values, expressiveness):
        try:
            score = float(score)
        except Exception:
            score = 1.0

        if score < threshold:
            continue

        idx = None

        if isinstance(label_value, int):
            idx = label_value

        elif isinstance(label_value, float):
            idx = int(label_value)

        elif isinstance(label_value, str):
            label_value_clean = label_value.strip()

            if label_value_clean.isdigit():
                idx = int(label_value_clean)
            elif label_value_clean in label2id:
                idx = label2id[label_value_clean]

        elif isinstance(label_value, dict):
            possible_label = (
                label_value.get("label")
                or label_value.get("emotion")
                or label_value.get("name")
                or label_value.get("id")
            )

            possible_score = (
                label_value.get("score")
                or label_value.get("expressiveness")
                or label_value.get("value")
            )

            if possible_score is not None:
                try:
                    score = float(possible_score)
                except Exception:
                    score = 1.0

            if score < threshold:
                continue

            if isinstance(possible_label, int):
                idx = possible_label
            elif isinstance(possible_label, str):
                if possible_label.isdigit():
                    idx = int(possible_label)
                elif possible_label in label2id:
                    idx = label2id[possible_label]

        if idx is not None and 0 <= idx < num_labels:
            y[idx] = 1.0

    return y


sample_y = make_multihot(
    get_label_indices(raw_sample),
    get_expressiveness(raw_sample),
    NUM_LABELS,
    threshold=CFG.LABEL_THRESHOLD
)

print("\nPositive labels in raw sample:")
print([LABELS[i] for i, v in enumerate(sample_y) if v == 1])


# ============================================================
# 7. Load JSONL Dataset
# ============================================================

def load_utterance_only_jsonl(path, num_labels, threshold=0.30):
    rows = []

    with open(path, "r", encoding="utf-8") as f:
        for line in tqdm(f, desc=f"Loading {path.name}"):
            line = line.strip()

            if not line:
                continue

            record = json.loads(line)

            utterance = get_utterance(record)

            label_values = get_label_indices(record)
            expressiveness = get_expressiveness(record)

            y = make_multihot(
                label_values=label_values,
                expressiveness=expressiveness,
                num_labels=num_labels,
                threshold=threshold
            )

            if len(utterance.strip()) == 0:
                continue

            if y.sum() == 0:
                continue

            rows.append({
                "utterance": utterance,
                "labels": y,
                "primary_emotion": record.get("primary_emotion", record.get("main_emotion", None)),
                "raw": record
            })

    return pd.DataFrame(rows)


train_df = load_utterance_only_jsonl(CFG.TRAIN_FILE, NUM_LABELS, CFG.LABEL_THRESHOLD)
dev_df   = load_utterance_only_jsonl(CFG.DEV_FILE, NUM_LABELS, CFG.LABEL_THRESHOLD)
test_df  = load_utterance_only_jsonl(CFG.TEST_FILE, NUM_LABELS, CFG.LABEL_THRESHOLD)

print("\nTrain shape:", train_df.shape)
print("Dev shape:", dev_df.shape)
print("Test shape:", test_df.shape)

if len(train_df) == 0 or len(dev_df) == 0 or len(test_df) == 0:
    raise ValueError("One of the splits is empty after filtering. Check labels/threshold/data path.")

print("\nProcessed sample:")
print("Utterance:", train_df.iloc[0]["utterance"])
print("Labels:", [LABELS[i] for i, v in enumerate(train_df.iloc[0]["labels"]) if v == 1])


# ============================================================
# 8. Tokenizer
# ============================================================

tokenizer = AutoTokenizer.from_pretrained(CFG.MODEL_NAME)


# ============================================================
# 9. Label Distribution Figure
# ============================================================

def label_distribution(df, labels):
    label_matrix = np.stack(df["labels"].values)
    counts = label_matrix.sum(axis=0)

    return pd.DataFrame({
        "label": labels,
        "count": counts.astype(int)
    }).sort_values("count", ascending=False)


dist_df = label_distribution(train_df, LABELS)
dist_df.to_csv(CFG.OUTPUT_DIR / "train_label_distribution.csv", index=False)

print("\nTraining label distribution:")
display(dist_df)

plt.figure(figsize=(12, 6))
plt.bar(dist_df["label"], dist_df["count"])
plt.xticks(rotation=90)
plt.xlabel("Emotion label")
plt.ylabel("Count")
plt.title("Training Label Distribution - ELECTRA Utterance-Only Full")
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_label_distribution.png", dpi=300)
plt.show()


# ============================================================
# 10. Token Length Figures
# ============================================================

def token_length_with_specials(text):
    encoded = tokenizer(
        str(text),
        add_special_tokens=True,
        truncation=False
    )
    return len(encoded["input_ids"])


train_df["utterance_token_len"] = train_df["utterance"].apply(token_length_with_specials)

length_summary = train_df[["utterance_token_len"]].describe()
length_summary.to_csv(CFG.OUTPUT_DIR / "token_length_summary.csv")

print("\nToken length summary:")
display(length_summary)

plt.figure(figsize=(8, 5))
plt.hist(train_df["utterance_token_len"], bins=50)
plt.axvline(CFG.MAX_LEN, linestyle="--")
plt.xlabel("Utterance token length")
plt.ylabel("Frequency")
plt.title("Utterance Token Length Distribution - ELECTRA Utterance-Only Full")
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_utterance_token_length.png", dpi=300)
plt.show()

num_truncated = int((train_df["utterance_token_len"] > CFG.MAX_LEN).sum())
print(f"\nExamples longer than MAX_LEN={CFG.MAX_LEN}: {num_truncated}")


# ============================================================
# 11. Dataset and DataLoader
# ============================================================

class UtteranceOnlyEmotionDataset(Dataset):
    def __init__(self, df, tokenizer, max_len):
        self.utterances = df["utterance"].tolist()
        self.labels = np.stack(df["labels"].values)
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.utterances)

    def __getitem__(self, idx):
        utterance = str(self.utterances[idx])
        labels = self.labels[idx]

        encoded = self.tokenizer(
            utterance,
            add_special_tokens=True,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_attention_mask=True,
            return_token_type_ids=True,
            return_tensors="pt"
        )

        token_type_ids = encoded.get(
            "token_type_ids",
            torch.zeros_like(encoded["input_ids"])
        )

        return {
            "input_ids": encoded["input_ids"].squeeze(0),
            "attention_mask": encoded["attention_mask"].squeeze(0),
            "token_type_ids": token_type_ids.squeeze(0),
            "labels": torch.tensor(labels, dtype=torch.float)
        }


train_dataset = UtteranceOnlyEmotionDataset(train_df, tokenizer, CFG.MAX_LEN)
dev_dataset   = UtteranceOnlyEmotionDataset(dev_df, tokenizer, CFG.MAX_LEN)
test_dataset  = UtteranceOnlyEmotionDataset(test_df, tokenizer, CFG.MAX_LEN)

train_loader = DataLoader(
    train_dataset,
    batch_size=CFG.BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=torch.cuda.is_available()
)

dev_loader = DataLoader(
    dev_dataset,
    batch_size=CFG.BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=torch.cuda.is_available()
)

test_loader = DataLoader(
    test_dataset,
    batch_size=CFG.BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=torch.cuda.is_available()
)


# ============================================================
# 12. Model
# ============================================================

class ElectraUtteranceOnlyEmotionClassifier(nn.Module):
    def __init__(self, model_name, num_labels, dropout=0.2):
        super().__init__()

        self.encoder = AutoModel.from_pretrained(model_name)
        hidden_size = self.encoder.config.hidden_size

        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden_size, num_labels)

    def forward(self, input_ids, attention_mask, token_type_ids=None):
        outputs = self.encoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        cls_representation = outputs.last_hidden_state[:, 0, :]
        cls_representation = self.dropout(cls_representation)

        logits = self.classifier(cls_representation)

        return logits


model = ElectraUtteranceOnlyEmotionClassifier(
    model_name=CFG.MODEL_NAME,
    num_labels=NUM_LABELS,
    dropout=0.2
)

model = model.to(device)


# ============================================================
# 13. Loss, Optimizer, Scheduler
# ============================================================

criterion = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    model.parameters(),
    lr=CFG.LR,
    weight_decay=CFG.WEIGHT_DECAY
)

total_steps = len(train_loader) * CFG.EPOCHS
warmup_steps = int(total_steps * CFG.WARMUP_RATIO)

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_steps
)

scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

print("\nTotal training steps:", total_steps)
print("Warmup steps:", warmup_steps)


# ============================================================
# 14. Metrics
# ============================================================

def compute_metrics(y_true, y_prob, threshold=0.30):
    y_pred = (y_prob >= threshold).astype(int)

    return {
        "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
        "micro_f1": f1_score(y_true, y_pred, average="micro", zero_division=0),
        "macro_precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0)
    }


def threshold_search_df(y_true, y_prob):
    rows = []

    for threshold in np.arange(0.05, 0.96, 0.01):
        y_pred = (y_prob >= threshold).astype(int)

        rows.append({
            "threshold": float(threshold),
            "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
            "macro_precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
            "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0)
        })

    return pd.DataFrame(rows)


def find_best_threshold(y_true, y_prob):
    th_df = threshold_search_df(y_true, y_prob)
    best_row = th_df.sort_values("macro_f1", ascending=False).iloc[0]

    return float(best_row["threshold"]), float(best_row["macro_f1"]), th_df


# ============================================================
# 15. Training and Evaluation
# ============================================================

def train_one_epoch(model, loader, optimizer, scheduler, criterion, device):
    model.train()

    total_loss = 0.0
    progress = tqdm(loader, desc="Training", leave=False)

    for batch in progress:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        token_type_ids = batch["token_type_ids"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                token_type_ids=token_type_ids
            )

            loss = criterion(logits, labels)

        scaler.scale(loss).backward()

        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        scaler.step(optimizer)
        scaler.update()
        scheduler.step()

        total_loss += loss.item()
        progress.set_postfix({"loss": loss.item()})

    return total_loss / len(loader)


@torch.no_grad()
def evaluate(model, loader, criterion, device, threshold=0.30):
    model.eval()

    total_loss = 0.0
    all_probs = []
    all_labels = []

    progress = tqdm(loader, desc="Evaluating", leave=False)

    for batch in progress:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        token_type_ids = batch["token_type_ids"].to(device)
        labels = batch["labels"].to(device)

        logits = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        loss = criterion(logits, labels)
        probs = torch.sigmoid(logits)

        total_loss += loss.item()

        all_probs.append(probs.cpu().numpy())
        all_labels.append(labels.cpu().numpy())

    y_prob = np.vstack(all_probs)
    y_true = np.vstack(all_labels)

    metrics = compute_metrics(
        y_true=y_true,
        y_prob=y_prob,
        threshold=threshold
    )

    avg_loss = total_loss / len(loader)

    return avg_loss, metrics, y_true, y_prob


# ============================================================
# 16. Training Loop
# ============================================================

best_macro_f1 = -1.0
best_model_path = CFG.OUTPUT_DIR / "best_model.pt"

history = []

for epoch in range(1, CFG.EPOCHS + 1):
    print(f"\n================ Epoch {epoch}/{CFG.EPOCHS} ================")

    train_loss = train_one_epoch(
        model=model,
        loader=train_loader,
        optimizer=optimizer,
        scheduler=scheduler,
        criterion=criterion,
        device=device
    )

    dev_loss, dev_metrics, dev_y_true, dev_y_prob = evaluate(
        model=model,
        loader=dev_loader,
        criterion=criterion,
        device=device,
        threshold=CFG.DEFAULT_PRED_THRESHOLD
    )

    print(f"Train loss: {train_loss:.4f}")
    print(f"Dev loss:   {dev_loss:.4f}")

    for metric_name, metric_value in dev_metrics.items():
        print(f"{metric_name}: {metric_value:.4f}")

    row = {
        "epoch": epoch,
        "train_loss": train_loss,
        "dev_loss": dev_loss,
        **dev_metrics
    }

    history.append(row)

    if dev_metrics["macro_f1"] > best_macro_f1:
        best_macro_f1 = dev_metrics["macro_f1"]
        torch.save(model.state_dict(), best_model_path)

        print(f"Saved best model to: {best_model_path}")
        print(f"Best dev macro F1: {best_macro_f1:.4f}")


history_df = pd.DataFrame(history)
history_df.to_csv(CFG.OUTPUT_DIR / "training_history.csv", index=False)

print("\nTraining finished.")
display(history_df)


# ============================================================
# 17. Training Curve Figures
# ============================================================

plt.figure(figsize=(8, 5))
plt.plot(history_df["epoch"], history_df["train_loss"], marker="o", label="train_loss")
plt.plot(history_df["epoch"], history_df["dev_loss"], marker="o", label="dev_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Dev Loss - ELECTRA Utterance-Only Full")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_loss_curve.png", dpi=300)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history_df["epoch"], history_df["macro_f1"], marker="o", label="macro_f1")
plt.plot(history_df["epoch"], history_df["micro_f1"], marker="o", label="micro_f1")
plt.xlabel("Epoch")
plt.ylabel("F1-score")
plt.title("Dev F1 Curve - ELECTRA Utterance-Only Full")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_dev_f1_curve.png", dpi=300)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history_df["epoch"], history_df["macro_precision"], marker="o", label="macro_precision")
plt.plot(history_df["epoch"], history_df["macro_recall"], marker="o", label="macro_recall")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("Dev Precision and Recall Curve")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_dev_precision_recall_curve.png", dpi=300)
plt.show()


# ============================================================
# 18. Load Best Model and Tune Threshold
# ============================================================

model.load_state_dict(torch.load(best_model_path, map_location=device))
model = model.to(device)

dev_loss, dev_metrics_default, dev_y_true, dev_y_prob = evaluate(
    model=model,
    loader=dev_loader,
    criterion=criterion,
    device=device,
    threshold=CFG.DEFAULT_PRED_THRESHOLD
)

best_threshold, best_dev_f1, threshold_df = find_best_threshold(
    y_true=dev_y_true,
    y_prob=dev_y_prob
)

threshold_df.to_csv(CFG.OUTPUT_DIR / "threshold_search.csv", index=False)

with open(CFG.OUTPUT_DIR / "best_threshold.txt", "w") as f:
    f.write(str(best_threshold))

print("\nBest threshold:", best_threshold)
print("Best dev macro F1:", best_dev_f1)

display(threshold_df.sort_values("macro_f1", ascending=False).head(10))


# ============================================================
# 19. Threshold Search Figure
# ============================================================

plt.figure(figsize=(8, 5))
plt.plot(threshold_df["threshold"], threshold_df["macro_f1"], label="macro_f1")
plt.plot(threshold_df["threshold"], threshold_df["macro_precision"], label="macro_precision")
plt.plot(threshold_df["threshold"], threshold_df["macro_recall"], label="macro_recall")
plt.axvline(best_threshold, linestyle="--", label=f"best={best_threshold:.2f}")
plt.xlabel("Prediction threshold")
plt.ylabel("Score")
plt.title("Threshold Search on Dev Set")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_threshold_search.png", dpi=300)
plt.show()


# ============================================================
# 20. Final Test Evaluation
# ============================================================

test_loss, test_metrics_default, test_y_true, test_y_prob = evaluate(
    model=model,
    loader=test_loader,
    criterion=criterion,
    device=device,
    threshold=CFG.DEFAULT_PRED_THRESHOLD
)

test_metrics_best = compute_metrics(
    y_true=test_y_true,
    y_prob=test_y_prob,
    threshold=best_threshold
)

print("\n================ FINAL TEST RESULTS ================")
print(f"Test loss: {test_loss:.4f}")

print("\nUsing default threshold:", CFG.DEFAULT_PRED_THRESHOLD)
for metric_name, metric_value in test_metrics_default.items():
    print(f"{metric_name}: {metric_value:.4f}")

print("\nUsing best dev threshold:", round(best_threshold, 3))
for metric_name, metric_value in test_metrics_best.items():
    print(f"{metric_name}: {metric_value:.4f}")


result_df = pd.DataFrame([
    {
        "model": "electra_utterance_only_full",
        "input": "utterance only",
        "dataset": "context-less",
        "threshold_type": "default",
        "threshold": CFG.DEFAULT_PRED_THRESHOLD,
        **test_metrics_default
    },
    {
        "model": "electra_utterance_only_full",
        "input": "utterance only",
        "dataset": "context-less",
        "threshold_type": "best_dev",
        "threshold": best_threshold,
        **test_metrics_best
    }
])

result_df.to_csv(CFG.OUTPUT_DIR / "test_results.csv", index=False)

print("\nTest result table:")
display(result_df)


# ============================================================
# 21. Classification Report
# ============================================================

test_y_pred = (test_y_prob >= best_threshold).astype(int)

report = classification_report(
    test_y_true,
    test_y_pred,
    target_names=LABELS,
    zero_division=0,
    output_dict=True
)

report_df = pd.DataFrame(report).transpose()
report_df.to_csv(CFG.OUTPUT_DIR / "classification_report.csv")

print("\nClassification report:")
display(report_df)


# ============================================================
# 22. Per-Class F1 Figure
# ============================================================

per_class_df = report_df.loc[LABELS].reset_index()
per_class_df = per_class_df.rename(columns={"index": "label"})
per_class_df = per_class_df.sort_values("f1-score", ascending=False)

per_class_df.to_csv(CFG.OUTPUT_DIR / "per_class_scores.csv", index=False)

plt.figure(figsize=(12, 6))
plt.bar(per_class_df["label"], per_class_df["f1-score"])
plt.xticks(rotation=90)
plt.xlabel("Emotion label")
plt.ylabel("F1-score")
plt.title("Per-Class F1 - ELECTRA Utterance-Only Full")
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_per_class_f1.png", dpi=300)
plt.show()


# ============================================================
# 23. Per-Class Precision and Recall Figure
# ============================================================

plt.figure(figsize=(12, 6))
x = np.arange(len(per_class_df))
width = 0.4

plt.bar(x - width / 2, per_class_df["precision"], width, label="precision")
plt.bar(x + width / 2, per_class_df["recall"], width, label="recall")

plt.xticks(x, per_class_df["label"], rotation=90)
plt.xlabel("Emotion label")
plt.ylabel("Score")
plt.title("Per-Class Precision and Recall")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_per_class_precision_recall.png", dpi=300)
plt.show()


# ============================================================
# 24. True vs Predicted Counts Figure
# ============================================================

true_counts = test_y_true.sum(axis=0)
pred_counts = test_y_pred.sum(axis=0)

count_compare_df = pd.DataFrame({
    "label": LABELS,
    "true_count": true_counts.astype(int),
    "predicted_count": pred_counts.astype(int)
}).sort_values("true_count", ascending=False)

count_compare_df.to_csv(CFG.OUTPUT_DIR / "true_vs_predicted_counts.csv", index=False)

print("\nTrue vs predicted label counts:")
display(count_compare_df)

x = np.arange(len(count_compare_df))
width = 0.4

plt.figure(figsize=(12, 6))
plt.bar(x - width / 2, count_compare_df["true_count"], width, label="true")
plt.bar(x + width / 2, count_compare_df["predicted_count"], width, label="predicted")
plt.xticks(x, count_compare_df["label"], rotation=90)
plt.xlabel("Emotion label")
plt.ylabel("Count")
plt.title("True vs Predicted Label Counts")
plt.legend()
plt.tight_layout()
plt.savefig(CFG.FIGURE_DIR / "figure_true_vs_predicted_counts.png", dpi=300)
plt.show()


# ============================================================
# 25. Save Model Config and Tokenizer
# ============================================================

tokenizer.save_pretrained(CFG.OUTPUT_DIR)

config = {
    "model_name": CFG.MODEL_NAME,
    "model_type": "electra_utterance_only_full",
    "input_format": "utterance only",
    "dataset": "context-less",
    "num_labels": NUM_LABELS,
    "labels": LABELS,
    "label2id": label2id,
    "id2label": id2label,
    "max_len": CFG.MAX_LEN,
    "best_threshold": best_threshold,
    "label_threshold": CFG.LABEL_THRESHOLD,
    "batch_size": CFG.BATCH_SIZE,
    "epochs": CFG.EPOCHS,
    "learning_rate": CFG.LR
}

with open(CFG.OUTPUT_DIR / "config.json", "w", encoding="utf-8") as f:
    json.dump(config, f, indent=2, ensure_ascii=False)

print("\nModel/tokenizer/config saved.")


# ============================================================
# 26. Inference Function
# ============================================================

@torch.no_grad()
def predict_emotions_utterance_only(
    utterance,
    model,
    tokenizer,
    labels,
    threshold=None,
    top_k=8
):
    model.eval()

    if threshold is None:
        threshold = best_threshold

    encoded = tokenizer(
        str(utterance),
        add_special_tokens=True,
        max_length=CFG.MAX_LEN,
        padding="max_length",
        truncation=True,
        return_attention_mask=True,
        return_token_type_ids=True,
        return_tensors="pt"
    )

    input_ids = encoded["input_ids"].to(device)
    attention_mask = encoded["attention_mask"].to(device)

    token_type_ids = encoded.get("token_type_ids", None)
    if token_type_ids is not None:
        token_type_ids = token_type_ids.to(device)

    logits = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids=token_type_ids
    )

    probs = torch.sigmoid(logits).cpu().numpy()[0]

    selected = []

    for i, p in enumerate(probs):
        if p >= threshold:
            selected.append({
                "emotion": labels[i],
                "score": float(p)
            })

    selected = sorted(selected, key=lambda x: x["score"], reverse=True)

    top_predictions = sorted(
        [
            {
                "emotion": labels[i],
                "score": float(probs[i])
            }
            for i in range(len(labels))
        ],
        key=lambda x: x["score"],
        reverse=True
    )[:top_k]

    return {
        "selected_emotions": selected,
        "top_predictions": top_predictions
    }


example_utterance = "I cannot believe this finally happened."

prediction = predict_emotions_utterance_only(
    utterance=example_utterance,
    model=model,
    tokenizer=tokenizer,
    labels=LABELS,
    threshold=best_threshold,
    top_k=8
)

print("\nExample utterance:")
print(example_utterance)

print("\nSelected emotions:")
print(prediction["selected_emotions"])

print("\nTop predictions:")
print(prediction["top_predictions"])


# ============================================================
# 27. Save Test Predictions
# ============================================================

def create_prediction_df(df, y_prob, threshold, labels):
    rows = []

    for i in range(len(df)):
        probs = y_prob[i]
        pred_indices = np.where(probs >= threshold)[0]

        pred_labels = [labels[j] for j in pred_indices]
        pred_scores = [float(probs[j]) for j in pred_indices]

        true_indices = np.where(df.iloc[i]["labels"] == 1)[0]
        true_labels = [labels[j] for j in true_indices]

        rows.append({
            "utterance": df.iloc[i]["utterance"],
            "true_primary_emotion": df.iloc[i]["primary_emotion"],
            "true_labels": true_labels,
            "predicted_labels": pred_labels,
            "predicted_scores": pred_scores
        })

    return pd.DataFrame(rows)


pred_df = create_prediction_df(
    df=test_df,
    y_prob=test_y_prob,
    threshold=best_threshold,
    labels=LABELS
)

pred_path = CFG.OUTPUT_DIR / "test_predictions.csv"
pred_df.to_csv(pred_path, index=False)

print("\nSaved predictions to:", pred_path)
display(pred_df.head(10))


# ============================================================
# 28. Zip All Generated Figures
# ============================================================

figure_zip_path = shutil.make_archive(
    base_name=str(CFG.FIGURE_ZIP_NAME),
    format="zip",
    root_dir=str(CFG.FIGURE_DIR)
)

print("\nAll figures saved in folder:")
print(CFG.FIGURE_DIR)

print("\nFigure ZIP file created:")
print(figure_zip_path)

print("\nFiles inside figure folder:")
for file_name in os.listdir(CFG.FIGURE_DIR):
    print("-", file_name)

print("\nFiles inside output folder:")
for file_name in os.listdir(CFG.OUTPUT_DIR):
    print("-", file_name)
# Out:
# Train file: /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/train.jsonl
# Dev file: /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/dev.jsonl
# Test file: /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/context-less/test.jsonl
# Label file: /kaggle/input/datasets/muhammadsaad003/cse495b/NLP dataset/labels.txt
# Output dir: /kaggle/working/electra_utterance_only_full
# Figure dir: /kaggle/working/electra_utterance_only_full/ELECTRA_utterance_only_full_figures
#
# All required files found.
#
# Device: cuda
# GPU: Tesla T4
#
# Number of labels: 28
# ['admiration', 'amusement', 'anger', 'annoyance', 'approval', 'caring', 'confusion', 'curiosity', 'desire', 'disappointment', 'disapproval', 'disgust', 'embarrassment', 'excitement', 'fear', 'gratitude', 'grief', 'joy', 'love', 'nervousness', 'optimism', 'pride', 'realization', 'relief', 'remorse', 'sadness', 'surprise', 'neutral']
#
# Raw sample keys:
# dict_keys(['plot_id', 'utterance', 'labels', 'expressiveness', 'primary_emotion', 'all_emotions', 'all_emotions_mapped', 'emotions_used_to_generate_context', 'raw_emotion_explication'])
#
# Raw sample preview:
# {
#   "plot_id": 356,
#   "utterance": "He's right. We have become heartless. We need to remember the humanity we've lost.",
#   "labels": [
#     "22",
#     "25",
#     "24",
#     "2"
#   ],
#   "expressiveness": [
#     1.0,
#     0.8,
#     0.9,
#     0.4
#   ],
#   "primary_emotion": "realization",
#   "all_emotions": [
#     [
#       "realization",
#       1.0
#     ],
#     [
#       "sadness",
#       0.8
#     ],
#     [
#       "compassion",
#       0.6
#     ],
#     [
#       "anger",
#       0.4
#     ],
#     [
#       "regret",
#       0.9
#     ]
#   ],
#   "all_emotions_mapped": [
#     [
#       "realization",
#       1.0
#     ],
#     [
#       "sadness",
#       0.8
#     ],
#     [
#       "remorse",
#       0.6
#     ],
#     [
#       "anger",
#       0.4
#     ],
#     [
#       "remorse",
#       0.9
#     ]
#   ],
#   "emotions_used_to_generate_context": [
#     "realization",
#     "sadness",
#     "remorse",
#     "anger"
#   ],
#   "raw_emotion_explication": "1. realization: 1.0\n2. sadness: 0.8\n3. compassion: 0.6\n4. anger: 0.4\n5. regret: 0.9\nExplanation:\nThe speaker realizes that they have lost touch with their humanity. This realization is expressed with a high level of intensity (1.0). The speaker also expresses sadness (0.8) about this loss, as well as compassion (0"
# }
#
# Positive labels in raw sample:
# ['anger', 'realization', 'remorse', 'sadness']
# Loading train.jsonl: 0it [00:00, ?it/s]
# Loading dev.jsonl: 0it [00:00, ?it/s]
# Loading test.jsonl: 0it [00:00, ?it/s]
# Train shape: (266456, 4)
# Dev shape: (33298, 4)
# Test shape: (33302, 4)
#
# Processed sample:
# Utterance: He's right. We have become heartless. We need to remember the humanity we've lost.
# Labels: ['anger', 'realization', 'remorse', 'sadness']
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Training label distribution:
#              label  count
# 19     nervousness  67684
# 6        confusion  66802
# 9   disappointment  65301
# 2            anger  59290
# 14            fear  50029
# 25         sadness  46542
# 3        annoyance  45228
# 26        surprise  43697
# 8           desire  43107
# 7        curiosity  40172
# 13      excitement  36036
# 17             joy  32870
# 0       admiration  32404
# 20        optimism  25833
# 21           pride  24829
# 5           caring  23157
# 27         neutral  22810
# 10     disapproval  22790
# 11         disgust  15387
# 18            love  13509
# 4         approval  10848
# 23          relief  10480
# 24         remorse  10273
# 1        amusement   9832
# 15       gratitude   8200
# 16           grief   7113
# 22     realization   5477
# 12   embarrassment   5298
# Token length summary:
#        utterance_token_len
# count        266456.000000
# mean             20.904352
# std               5.753412
# min               3.000000
# 25%              17.000000
# 50%              21.000000
# 75%              24.000000
# max              71.000000
# Examples longer than MAX_LEN=256: 0
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# ElectraModel LOAD REPORT from: google/electra-base-discriminator
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# discriminator_predictions.dense.bias              | UNEXPECTED |  |
# discriminator_predictions.dense_prediction.bias   | UNEXPECTED |  |
# discriminator_predictions.dense_prediction.weight | UNEXPECTED |  |
# discriminator_predictions.dense.weight            | UNEXPECTED |  |
# electra.embeddings_project.weight                 | UNEXPECTED |  |
# electra.embeddings_project.bias                   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Total training steps: 99921
# Warmup steps: 9992
#
# ================ Epoch 1/3 ================
# Training:   0%|          | 0/33307 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4163 [00:00<?, ?it/s]
# Train loss: 0.1542
# Dev loss:   0.1081
# macro_f1: 0.7581
# micro_f1: 0.7965
# macro_precision: 0.7222
# macro_recall: 0.8069
# Saved best model to: /kaggle/working/electra_utterance_only_full/best_model.pt
# Best dev macro F1: 0.7581
#
# ================ Epoch 2/3 ================
# Training:   0%|          | 0/33307 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4163 [00:00<?, ?it/s]
# Train loss: 0.0991
# Dev loss:   0.0986
# macro_f1: 0.7808
# micro_f1: 0.8155
# macro_precision: 0.7456
# macro_recall: 0.8257
# Saved best model to: /kaggle/working/electra_utterance_only_full/best_model.pt
# Best dev macro F1: 0.7808
#
# ================ Epoch 3/3 ================
# Training:   0%|          | 0/33307 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4163 [00:00<?, ?it/s]
# Train loss: 0.0824
# Dev loss:   0.0960
# macro_f1: 0.7881
# micro_f1: 0.8214
# macro_precision: 0.7463
# macro_recall: 0.8383
# Saved best model to: /kaggle/working/electra_utterance_only_full/best_model.pt
# Best dev macro F1: 0.7881
#
# Training finished.
#    epoch  train_loss  dev_loss  macro_f1  micro_f1  macro_precision  \
# 0      1    0.154223  0.108127  0.758135  0.796488         0.722158
# 1      2    0.099087  0.098553  0.780814  0.815500         0.745614
# 2      3    0.082442  0.095970  0.788062  0.821443         0.746306
#
#    macro_recall
# 0      0.806884
# 1      0.825659
# 2      0.838267
# Evaluating:   0%|          | 0/4163 [00:00<?, ?it/s]
# Best threshold: 0.42000000000000004
# Best dev macro F1: 0.7949332651954247
#     threshold  macro_f1  macro_precision  macro_recall
# 37       0.42  0.794933         0.794248      0.798927
# 36       0.41  0.794905         0.790853      0.802269
# 38       0.43  0.794828         0.797419      0.795583
# 39       0.44  0.794821         0.800874      0.792186
# 40       0.45  0.794748         0.804137      0.788964
# 41       0.46  0.794660         0.807493      0.785675
# 35       0.40  0.794657         0.787139      0.805609
# 34       0.39  0.794620         0.783468      0.809398
# 42       0.47  0.794481         0.810949      0.782148
# 43       0.48  0.794459         0.814474      0.778960
# Evaluating:   0%|          | 0/4163 [00:00<?, ?it/s]
# ================ FINAL TEST RESULTS ================
# Test loss: 0.0956
#
# Using default threshold: 0.3
# macro_f1: 0.7904
# micro_f1: 0.8216
# macro_precision: 0.7487
# macro_recall: 0.8400
#
# Using best dev threshold: 0.42
# macro_f1: 0.7968
# micro_f1: 0.8296
# macro_precision: 0.7966
# macro_recall: 0.7999
#
# Test result table:
#                          model           input       dataset threshold_type  \
# 0  electra_utterance_only_full  utterance only  context-less        default
# 1  electra_utterance_only_full  utterance only  context-less       best_dev
#
#    threshold  macro_f1  micro_f1  macro_precision  macro_recall
# 0       0.30  0.790408  0.821586         0.748692       0.84002
# 1       0.42  0.796785  0.829591         0.796619       0.79992
# Classification report:
#                 precision    recall  f1-score   support
# admiration       0.795070  0.799903  0.797479    4113.0
# amusement        0.853383  0.723506  0.783096    1255.0
# anger            0.878887  0.912012  0.895143    7376.0
# annoyance        0.844932  0.862203  0.853480    5675.0
# approval         0.593032  0.551141  0.571320    1359.0
# caring           0.724858  0.783590  0.753080    2925.0
# confusion        0.817129  0.837713  0.827293    8257.0
# curiosity        0.869377  0.873495  0.871431    5067.0
# desire           0.816425  0.874515  0.844472    5411.0
# disappointment   0.845497  0.877679  0.861287    8118.0
# disapproval      0.671577  0.648508  0.659841    2882.0
# disgust          0.808355  0.814308  0.811321    1901.0
# embarrassment    0.744648  0.677330  0.709395     719.0
# excitement       0.779737  0.810018  0.794589    4532.0
# fear             0.886558  0.911262  0.898740    6029.0
# gratitude        0.855135  0.799798  0.826541     989.0
# grief            0.733524  0.813559  0.771472     944.0
# joy              0.769507  0.887561  0.824329    4100.0
# love             0.764120  0.800000  0.781648    1725.0
# nervousness      0.826166  0.868049  0.846590    8344.0
# optimism         0.838928  0.847542  0.843213    3214.0
# pride            0.890110  0.897436  0.893758    3159.0
# realization      0.800425  0.593701  0.681736     635.0
# relief           0.765823  0.821887  0.792865    1325.0
# remorse          0.695473  0.651503  0.672771    1297.0
# sadness          0.805152  0.897806  0.848959    5744.0
# surprise         0.853941  0.868464  0.861141    5527.0
# neutral          0.777561  0.693273  0.733002    2869.0
# micro avg        0.818065  0.841446  0.829591  105491.0
# macro avg        0.796619  0.799920  0.796785  105491.0
# weighted avg     0.817873  0.841446  0.828846  105491.0
# samples avg      0.832668  0.851959  0.825853  105491.0
# True vs predicted label counts:
#              label  true_count  predicted_count
# 19     nervousness        8344             8767
# 6        confusion        8257             8465
# 9   disappointment        8118             8427
# 2            anger        7376             7654
# 14            fear        6029             6197
# 25         sadness        5744             6405
# 3        annoyance        5675             5791
# 26        surprise        5527             5621
# 8           desire        5411             5796
# 7        curiosity        5067             5091
# 13      excitement        4532             4708
# 0       admiration        4113             4138
# 17             joy        4100             4729
# 20        optimism        3214             3247
# 21           pride        3159             3185
# 5           caring        2925             3162
# 10     disapproval        2882             2783
# 27         neutral        2869             2558
# 11         disgust        1901             1915
# 18            love        1725             1806
# 4         approval        1359             1263
# 23          relief        1325             1422
# 24         remorse        1297             1215
# 1        amusement        1255             1064
# 15       gratitude         989              925
# 16           grief         944             1047
# 12   embarrassment         719              654
# 22     realization         635              471
# Model/tokenizer/config saved.
#
# Example utterance:
# I cannot believe this finally happened.
#
# Selected emotions:
# [{'emotion': 'surprise', 'score': 0.9876039028167725}, {'emotion': 'joy', 'score': 0.9839358329772949}, {'emotion': 'relief', 'score': 0.9771554470062256}, {'emotion': 'excitement', 'score': 0.7928036451339722}]
#
# Top predictions:
# [{'emotion': 'surprise', 'score': 0.9876039028167725}, {'emotion': 'joy', 'score': 0.9839358329772949}, {'emotion': 'relief', 'score': 0.9771554470062256}, {'emotion': 'excitement', 'score': 0.7928036451339722}, {'emotion': 'admiration', 'score': 0.06396488845348358}, {'emotion': 'pride', 'score': 0.05687765032052994}, {'emotion': 'disapproval', 'score': 0.03441430255770683}, {'emotion': 'gratitude', 'score': 0.008240321651101112}]
#
# Saved predictions to: /kaggle/working/electra_utterance_only_full/test_predictions.csv
#                                            utterance true_primary_emotion  \
# 0  Sebastian's injuries aren't as bad as I though...             surprise
# 1  I wish I could feel human emotions like love o...              longing
# 2  I truly hope that this'mixing of minds' does m...                 love
# 3  We failed to capture the French castle. We wer...       disappointment
# 4  I can't believe those nihilists burned down th...                anger
# 5  How dare that coach talk down to Eric like tha...                anger
# 6  I didn't expect Shevek to be such a passionate...             surprise
# 7  I'm so proud of my dad and his team. They've w...                 love
# 8  Byam's acquittal? I can't believe it. The Brit...             surprise
# 9  I wonder what lies ahead on our journey to fin...              neutral
#
#                                         true_labels  \
# 0              [approval, caring, relief, surprise]
# 1                 [curiosity, disapproval, sadness]
# 2                                  [love, optimism]
# 3     [annoyance, desire, disappointment, optimism]
# 4   [anger, annoyance, disappointment, disapproval]
# 5           [admiration, anger, disapproval, pride]
# 6                            [admiration, surprise]
# 7                    [admiration, joy, love, pride]
# 8  [disappointment, disapproval, disgust, surprise]
# 9                              [curiosity, neutral]
#
#                                 predicted_labels  \
# 0                               [caring, relief]
# 1        [confusion, curiosity, desire, sadness]
# 2                     [caring, desire, optimism]
# 3  [annoyance, desire, disappointment, optimism]
# 4    [anger, annoyance, disappointment, disgust]
# 5         [anger, approval, caring, disapproval]
# 6                         [admiration, surprise]
# 7       [admiration, approval, joy, love, pride]
# 8           [disapproval, joy, relief, surprise]
# 9                        [curiosity, excitement]
#
#                                     predicted_scores
# 0           [0.6908338069915771, 0.9924528002738953]
# 1  [0.8028682470321655, 0.5164664387702942, 0.891...
# 2  [0.49920713901519775, 0.4296939969062805, 0.99...
# 3  [0.9622966051101685, 0.9724900722503662, 0.986...
# 4  [0.9966588020324707, 0.9406858086585999, 0.490...
# 5  [0.9823926687240601, 0.48030856251716614, 0.75...
# 6            [0.9945303797721863, 0.996408998966217]
# 7  [0.768558144569397, 0.6232850551605225, 0.8720...
# 8  [0.8456975221633911, 0.5528796911239624, 0.884...
# 9           [0.9987525939941406, 0.9867114424705505]
# All figures saved in folder:
# /kaggle/working/electra_utterance_only_full/ELECTRA_utterance_only_full_figures
#
# Figure ZIP file created:
# /kaggle/working/electra_utterance_only_full/ELECTRA_utterance_only_full_figures.zip
#
# Files inside figure folder:
# - figure_utterance_token_length.png
# - figure_dev_precision_recall_curve.png
# - figure_label_distribution.png
# - figure_dev_f1_curve.png
# - figure_true_vs_predicted_counts.png
# - figure_per_class_f1.png
# - figure_threshold_search.png
# - figure_loss_curve.png
# - figure_per_class_precision_recall.png
#
# Files inside output folder:
# - per_class_scores.csv
# - train_label_distribution.csv
# - token_length_summary.csv
# - best_threshold.txt
# - true_vs_predicted_counts.csv
# - ELECTRA_utterance_only_full_figures.zip
# - best_model.pt
# - test_results.csv
# - ELECTRA_utterance_only_full_figures
# - training_history.csv
# - classification_report.csv
# - tokenizer.json
# - config.json
# - threshold_search.csv
# - test_predictions.csv
# - tokenizer_config.json
